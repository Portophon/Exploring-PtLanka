# %% [markdown]
# ## Packages

# %%
import pandas as pd
import re

# %% [markdown]
# ## Load data set

# %%
file_name = "PtLanka-final.csv"

word_df = pd.read_csv(file_name)


word_df = word_df[~word_df.Portuguese_IPA.isnull()]
word_df
# Out:
#       Unnamed: 0 SriLanka_creole phonetic_transcription Portuguese_definition  \
# 0              0           Abaço                  abaso                abaixo
# 1              1          Aberçà                abeɾsaː               abraçar
# 2              2          abersà                abeɾsaː               abraçar
# 3              3          aburçá                abuɾsaː               abraçar
# 4              4          Aburcé                abuɾseː             aborrecer
# ...          ...             ...                    ...                   ...
# 2499        2499           Virrá                  ʋiraː                 virar
# 2501        2501           Vistê                 ʋisteː                vestir
# 2502        2502           vistá                 ʋistaː                vestir
# 2507        2507           Vizia                  ʋizia                 vigia
# 2508        2508           Viziá                 ʋiziaː                vigiar
#
# ...

# %%
word_list = word_df["SriLanka_creole"]
word_list
# Out:
# 0        Abaço
# 1       Aberçà
# 2       abersà
# 3       aburçá
# 4       Aburcé
#          ...
# 2499     Virrá
# 2501     Vistê
# 2502     vistá
# 2507     Vizia
# 2508     Viziá
# Name: SriLanka_creole, Length: 974, dtype: object

# %%
word_list = [i.lower() for i in word_list]
word_list[0:10]
# Out:
# ['abaço',
#  'aberçà',
#  'abersà',
#  'aburçá',
#  'aburcé',
#  'aborcido',
#  'absença',
#  'acá',
#  'açorague',
#  'adéo']

# %% [markdown]
# # Convert to IPA

# %%
word_list = [re.sub("s$","s", i) for i in word_list]
word_list = [re.sub("z$","s", i) for i in word_list]
word_list = [re.sub("g$","g", i) for i in word_list]
word_list = [re.sub("c$","k", i) for i in word_list]

word_list = [re.sub("tch","t̠ʃ", i) for i in word_list]
word_list = [re.sub("ch","t̠ʃ", i) for i in word_list]
word_list = [re.sub("dj","d̠ʒ", i) for i in word_list]
word_list = [re.sub("j","d̠ʒ", i) for i in word_list]

word_list = [re.sub("(?<=[aáàâãeéèêiíìoóòôõuúùûmnlrtpqcy])s","s", i) for i in word_list]
word_list = [re.sub("g(?=[eéèêiíì])","d̠ʒ", i) for i in word_list]
word_list = [re.sub("gg","g", i) for i in word_list]
word_list = [re.sub("g(?=[drlnaáàâãoóòôõuúùû])","g", i) for i in word_list]
word_list = [re.sub("gu(?=[eéèêiíì])","g", i) for i in word_list]
word_list = [re.sub("[vw]","ʋ", i) for i in word_list]
word_list = [re.sub("nh","ɲ", i) for i in word_list]
word_list = [re.sub("lh","ʎ", i) for i in word_list]
word_list = [re.sub("z(?=[aáàâãeéèêiíìoóòôõuúùû\-])","z", i) for i in word_list]
word_list = [re.sub("(?<=[aáàâãeéèêiíìoóòôõuúùû])s(?=[aáàâãeéèêiíìoóòôõuúùû])","z", i) for i in word_list]
word_list = [re.sub("s(?=[rmnlbdgvj])","z", i) for i in word_list]
word_list = [re.sub("p","p", i) for i in word_list]
word_list = [re.sub("pp","p", i) for i in word_list]
word_list = [re.sub("b","b", i) for i in word_list]
word_list = [re.sub("d","d", i) for i in word_list]
word_list = [re.sub("cc(?=[aáàâãoóòôõuúùû])","k", i) for i in word_list]
word_list = [re.sub("c(?=[tkrlçaáàâãoóòôõuúùû])","k", i) for i in word_list]
word_list = [re.sub("k","k", i) for i in word_list]
word_list = [re.sub("ck","k", i) for i in word_list]
word_list = [re.sub("t","t", i) for i in word_list]
word_list = [re.sub("tt","tː", i) for i in word_list]
word_list = [re.sub("qu(?=[eéèêiíì])","k", i) for i in word_list]
word_list = [re.sub("q(?=u[aáàâãoóòôõ])","k", i) for i in word_list]
word_list = [re.sub("q","k", i) for i in word_list]
word_list = [re.sub("m","m", i) for i in word_list]
word_list = [re.sub("mm","m", i) for i in word_list]
word_list = [re.sub("n","n", i) for i in word_list]
word_list = [re.sub("ny","nʲ", i) for i in word_list]
word_list = [re.sub("ly","lʲ", i) for i in word_list]
word_list = [re.sub("ff","f", i) for i in word_list]
word_list = [re.sub("f","f", i) for i in word_list]
word_list = [re.sub("ph","f", i) for i in word_list]
word_list = [re.sub("sc(?=[eéèêiíì])","s", i) for i in word_list]
word_list = [re.sub("sç(?=[aáàâãoóòôõuúùû])","s", i) for i in word_list]
word_list = [re.sub("ss","s", i) for i in word_list]
word_list = [re.sub("s(?=[aáàâãeéèêiíìoóòôõuúùûptkcfsç])","s", i) for i in word_list]
word_list = [re.sub("ç","s", i) for i in word_list]
word_list = [re.sub("c(?=[eéèêiíì])","s", i) for i in word_list]
word_list = [re.sub("cs","ks", i) for i in word_list]
word_list = [re.sub("cc","s", i) for i in word_list]
word_list = [re.sub("^r","____", i) for i in word_list]
word_list = [re.sub("rr","____", i) for i in word_list]
word_list = [re.sub("r","ɾ", i) for i in word_list]
word_list = [re.sub("____","r", i) for i in word_list]
word_list = [re.sub("l","l", i) for i in word_list]
word_list = [re.sub("ll","l", i) for i in word_list]
word_list = [re.sub("y","j", i) for i in word_list]
word_list = [re.sub("(?<=[áàâéèêoóòôúùû])i","j", i) for i in word_list]
word_list = [re.sub("sh","ʃ", i) for i in word_list]
word_list = [re.sub("x","ʃ", i) for i in word_list]
word_list = [re.sub("u","u", i) for i in word_list]
word_list = [re.sub("[úùû]","uː", i) for i in word_list]
word_list = [re.sub("o","o", i) for i in word_list]
word_list = [re.sub("[óòõô]","oː", i) for i in word_list]
word_list = [re.sub("aa","a", i) for i in word_list]
word_list = [re.sub("a","a", i) for i in word_list]
word_list = [re.sub("[àáãâ]","aː", i) for i in word_list]
word_list = [re.sub("e","e", i) for i in word_list]
word_list = [re.sub("[éèê]","eː", i) for i in word_list]
word_list = [re.sub("i","i", i) for i in word_list]
word_list = [re.sub("[íìî]","iː", i) for i in word_list]
word_list = [re.sub("(?<=[ptkbdgmrɾsz])[j]","i", i) for i in word_list]
word_list = [re.sub("h","", i) for i in word_list]
word_list = [re.sub("-"," ", i) for i in word_list]
word_list = [re.sub("  ", " ", i) for i in word_list]
word_list = [re.sub("\.\.\.", " ", i) for i in word_list]
word_list = [re.sub("'", "ə", i) for i in word_list]
word_list = [re.sub("[cq]", " k ", i) for i in word_list]
word_list[0:10]
# Out:
# ['abaso',
#  'abeɾsaː',
#  'abeɾsaː',
#  'abuɾsaː',
#  'abuɾseː',
#  'aboɾsido',
#  'absensa',
#  'akaː',
#  'asoɾage',
#  'adeːo']

# %%
word_df["phonetic_transcription"] = word_list
word_df
# Out:
#       Unnamed: 0 SriLanka_creole phonetic_transcription Portuguese_definition  \
# 0              0           Abaço                  abaso                abaixo
# 1              1          Aberçà                abeɾsaː               abraçar
# 2              2          abersà                abeɾsaː               abraçar
# 3              3          aburçá                abuɾsaː               abraçar
# 4              4          Aburcé                abuɾseː             aborrecer
# ...          ...             ...                    ...                   ...
# 2499        2499           Virrá                  ʋiraː                 virar
# 2501        2501           Vistê                 ʋisteː                vestir
# 2502        2502           vistá                 ʋistaː                vestir
# 2507        2507           Vizia                  ʋizia                 vigia
# 2508        2508           Viziá                 ʋiziaː                vigiar
#
# ...

# %%
#word_df[word_df['phonetic_transcription'].str.contains("[nl]ʲ")]

# %%
word_df.fillna('', inplace=True)
word_df.to_csv("PtLanka_compare.csv", index = False, header = True)

# %% [markdown]
# # Convert to TRSVG

# %% [markdown]
# Before syllable parsing, we replaced the phonemes by larger categories:
#
# - T: corresponds to obstruents (consonants like T, which typically occur as first unit of an onset only);
#
# - R: corresponds to sonorants (consonants like R, which typically occur as onset- first or second unit- or coda);
#
# - V: corresponds to vowels;
#
# - G: corresponds to glides.

# %%
word_list = word_df["phonetic_transcription"]

# %%
word_list = [re.sub("papagaia", "papagVGa", i) for i in word_list]
word_list = [re.sub("peɾseguaisaːo", "peɾseguVGsaːo", i) for i in word_list]
word_list = [re.sub("peɾsuaidiɾ", "peɾsuVGdiɾ", i) for i in word_list]
word_list = [re.sub("aio", "VGo", i) for i in word_list]

word_list = [re.sub("s", "S", i) for i in word_list]
word_list = [re.sub("g", "T", i) for i in word_list]
word_list = [re.sub("k", "T", i) for i in word_list]
word_list = [re.sub("ʋ", "T", i) for i in word_list]
word_list = [re.sub("ɲ", "R", i) for i in word_list]
word_list = [re.sub("ʎ", "R", i) for i in word_list]
word_list = [re.sub("z", "S", i) for i in word_list]
word_list = [re.sub("p", "T", i) for i in word_list]
word_list = [re.sub("b", "T", i) for i in word_list]
word_list = [re.sub("t", "T", i) for i in word_list]
word_list = [re.sub("m", "R", i) for i in word_list]
word_list = [re.sub("nʲ", "R", i) for i in word_list]
word_list = [re.sub("n", "R", i) for i in word_list]
word_list = [re.sub("lʲ", "R", i) for i in word_list]
word_list = [re.sub("f", "T", i) for i in word_list]
word_list = [re.sub("ph", "T", i) for i in word_list]
word_list = [re.sub("r", "R", i) for i in word_list]
word_list = [re.sub("ɾ", "R", i) for i in word_list]
word_list = [re.sub("l", "R", i) for i in word_list]
word_list = [re.sub("d̠ʒ", "T", i) for i in word_list]
word_list = [re.sub("d", "T", i) for i in word_list]
word_list = [re.sub("j", "R", i) for i in word_list]
word_list = [re.sub("t̠ʃ", "T", i) for i in word_list]
word_list = [re.sub("T̠", "", i) for i in word_list]
word_list = [re.sub("ʃ", "T", i) for i in word_list]

word_list = [re.sub("eu", "VG", i) for i in word_list]
word_list = [re.sub("ei", "VG", i) for i in word_list]
word_list = [re.sub("oi", "VG", i) for i in word_list]
word_list = [re.sub("ou", "VG", i) for i in word_list]
word_list = [re.sub("au", "VG", i) for i in word_list]

word_list = [re.sub("u", "V", i) for i in word_list]
word_list = [re.sub("o", "V", i) for i in word_list]
word_list = [re.sub("a", "V", i) for i in word_list]
word_list = [re.sub("e", "V", i) for i in word_list]
word_list = [re.sub("i", "V", i) for i in word_list]
word_list = [re.sub("ə", "V", i) for i in word_list]
word_list = [re.sub("ː", "", i) for i in word_list]

word_list[0:10]
# Out:
# ['VTVSV',
#  'VTVRSV',
#  'VTVRSV',
#  'VTVRSV',
#  'VTVRSV',
#  'VTVRSVTV',
#  'VTSVRSV',
#  'VTV',
#  'VSVRVTV',
#  'VTVV']

# %% [markdown]
# # Split word

# %%
word_list = [re.sub("VT", "V.T", i) for i in word_list]
word_list = [re.sub("VGT", "VG.T", i) for i in word_list]
word_list = [re.sub("RT", "R.T", i) for i in word_list]
word_list = [re.sub("ST", "S.T", i) for i in word_list]
word_list = [re.sub("VRV", "V.RV", i) for i in word_list]
word_list = [re.sub("VRVG", "V.RVG", i) for i in word_list]
word_list = [re.sub("VGRV", "VG.RV", i) for i in word_list]
word_list = [re.sub("VGRVG", "VG.RVG", i) for i in word_list]
word_list = [re.sub("RSV", "R.SV", i) for i in word_list]
word_list = [re.sub("RSVG", "R.SVG", i) for i in word_list]
word_list = [re.sub("TSV", "T.SV", i) for i in word_list]
word_list = [re.sub("TSVG", "T.SVG", i) for i in word_list]
word_list = [re.sub("VSV", "V.SV", i) for i in word_list]
word_list = [re.sub("VGSV", "VG.SV", i) for i in word_list]
word_list = [re.sub("VSVG", "V.SVG", i) for i in word_list]
word_list = [re.sub("VGSVG", "VG.SVG", i) for i in word_list]
word_list = [re.sub("RR", "R.R", i) for i in word_list]
word_list = [re.sub("VV", "V.V", i) for i in word_list]
word_list = [re.sub("VGV", "VG.V", i) for i in word_list]
word_list = [re.sub("VVG", "V.VG", i) for i in word_list]
word_list = [re.sub("VGVG", "VGVG", i) for i in word_list]
word_list = [re.sub("TT", "T.T", i) for i in word_list]
word_list = [re.sub("SR", "S.R", i) for i in word_list]
word_list = [re.sub("SVSV", "SV.SV", i) for i in word_list]
word_list = [re.sub("RVGRV", "RVG.RV", i) for i in word_list]

# %% [markdown]
# # Convert to CV

# %%
word_df = word_df[["SriLanka_creole","phonetic_transcription"]]
word_df["phono_TRSVD"] = word_list
word_list_CV = [re.sub("VG", "VG", i) for i in word_list]
word_list_CV = [re.sub("[SRT]", "C", i) for i in word_list_CV]
word_df["phono_CV"] = word_list_CV
word_df
# Out:
# C:\Users\CARLOS~1\AppData\Local\Temp/ipykernel_3232/3373735984.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   word_df["phono_TRSVD"] = word_list
# C:\Users\CARLOS~1\AppData\Local\Temp/ipykernel_3232/3373735984.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   word_df["phono_CV"] = word_list_CV
#      SriLanka_creole phonetic_transcription phono_TRSVD  phono_CV
# 0              Abaço                  abaso     V.TV.SV   V.CV.CV
# ...

# %%
word_df[word_df['phonetic_transcription'].str.contains("d̠ʒ")]
# Out:
#      SriLanka_creole phonetic_transcription        phono_TRSVD  \
# 175        Avantagem            aʋantad̠ʒem       V.TVR.TV.TVR
# 261             Bijá                bid̠ʒaː              TV.TV
# 311          brimejo              bɾimed̠ʒo          TRV.RV.TV
# 392       Caringuejo            kaɾinged̠ʒo       TV.RVR.TV.TV
# 586           Coragè              koɾad̠ʒeː           TV.RV.TV
# 587           corajo               koɾad̠ʒo           TV.RV.TV
# 588          courajo              kouɾad̠ʒo          TVG.RV.TV
# 696          Deseijo              dezeid̠ʒo          TV.SVG.TV
# 698          Deseijà             dezeid̠ʒaː          TV.SVG.TV
# 887         Enjoelho              end̠ʒoeʎo         VR.TV.V.RV
# 897           Envéja              enʋeːd̠ʒa           VR.TV.TV
# 898           envejè              enʋed̠ʒeː           VR.TV.TV
# 899           envéjo              enʋeːd̠ʒo           VR.TV.TV
# 900          enveijo              enʋeid̠ʒo          VR.TVG.TV
# ...

# %%
word_df[word_df['phonetic_transcription'].str.contains("t̠ʃ")]
# Out:
#      SriLanka_creole phonetic_transcription phono_TRSVD    phono_CV
# 164            Atchà                 at̠ʃaː        V.TV        V.CV
# 341       Cachorinho             kat̠ʃoɾiɲo  TV.TV.RVRV  CV.CV.CVCV
# 431            Chalo                 t̠ʃalo       TV.RV       CV.CV
# 434            Chápè               t̠ʃaːpeː       TV.TV       CV.CV
# 435            Chape                 t̠ʃape       TV.TV       CV.CV
# 438             Chéo                 t̠ʃeːo        TV.V        CV.V
# 439            Chéro                t̠ʃeːɾo       TV.RV       CV.CV
# 440           chiero                t̠ʃieɾo     TV.V.RV     CV.V.CV
# 441          chiesto               t̠ʃiesto    TV.VS.TV    CV.VC.CV
# 442           chisto                t̠ʃisto      TVS.TV      CVC.CV
# 454        Chocarréa             t̠ʃokareːa  TV.TV.RV.V  CV.CV.CV.V
# 455        choqueria              t̠ʃokeɾia  TV.TV.RV.V  CV.CV.CV.V
# 456            Chomà                t̠ʃomaː       TV.RV       CV.CV
# ...

# %%
word_df[word_df['phono_CV'].str.contains("CVCʲV")]
# Out:
# Empty DataFrame
# Columns: [SriLanka_creole, phonetic_transcription, phono_TRSVD, phono_CV]
# Index: []

# %%
word_df.to_csv("crioulo_IPA_CV_compare.csv", index = False, header = True)
